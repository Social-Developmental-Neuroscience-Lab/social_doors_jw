# %% [markdown]
# # Run First Level Stats

# %%
import glob
from csv import reader


for i in glob.glob('../behavior/EVfiles/*'):
    sub_number = i[20:24]
    print(sub_number)
    with open('test_output.csv', 'r') as read_obj:
        csv_reader = reader(read_obj)
        # Iterate over each row in the csv using reader object
        for row in csv_reader:
            if sub_number == row[0][:4]:
                trial_type = row[0][-1:]
                nvols = row[2]
                condition = row[0][5:11]
                condition = condition.replace("_", "").capitalize()
                print(trial_type, nvols, condition)
                # !./models/L1_task-sr$condition$trial_type\_\model-01.sh $sub_number 2 0 6 $nvols
                # !./models/L1_task-sr$condition$trial_type\_\model-01.sh $sub_number 1 0 6 $nvols
        read_obj.close()
# Out:
# 3877
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 4020
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3967
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3882
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# child process exited abnormally
#     while executing
# "fsl:exec "${FSLDIR}/bin/feat_model design" $fmri(featModelOpts) -N feat0_model -l logs "
#     (procedure "firstLevelMaster" line 43)
#     invoked from within
# "firstLevelMaster $session"
#     invoked from within
# "if { $done_something == 0 } {
#
#     if { ! $fmri(inmelodic) } {
#        if { $fmri(level) == 1 } {
# 	      for { set session 1 } { $session <= $fmri(mult..."
#     (file "/usr/share/fsl/5.0/bin/feat" line 387)
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# child process exited abnormally
#     while executing
# "fsl:exec "${FSLDIR}/bin/feat_model design" $fmri(featModelOpts) -N feat0_model -l logs "
#     (procedure "firstLevelMaster" line 43)
#     invoked from within
# "firstLevelMaster $session"
#     invoked from within
# "if { $done_something == 0 } {
#
#     if { ! $fmri(inmelodic) } {
#        if { $fmri(level) == 1 } {
# 	      for { set session 1 } { $session <= $fmri(mult..."
#     (file "/usr/share/fsl/5.0/bin/feat" line 387)
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3847
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3852
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3836
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3865
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3883
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3849
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3920
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3890
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3886
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 4019
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3854
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 4017
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3846
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3845
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3889
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3848
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# ./models/L1_task-srDoorsa_model-01.sh: line 62: /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3848/L1_task-srDoorsa_model-01_seed-0_run-02_variant-dctAROMAnonaggr.fsf: No such file or directory
# grep: /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3848/L1_task-srDoorsa_model-01_seed-0_run-02_variant-dctAROMAnonaggr.fsf: No such file or directory
#     while executing
# "exec sh -c "grep -a 'fmri(inmelodic)' $filename | tail -n 1 | awk '{ print \$3 }'" "
#     (procedure "feat5:load" line 5)
#     invoked from within
# "feat5:load -1 1 ${fsfroot}.fsf"
#     (file "/usr/share/fsl/5.0/bin/feat" line 306)
# /data/projects/STUDIES/social_doors_college
# child process exited abnormally
#     while executing
# "fsl:exec "${FSLDIR}/bin/feat_model design" $fmri(featModelOpts) -N feat0_model -l logs "
#     (procedure "firstLevelMaster" line 43)
#     invoked from within
# "firstLevelMaster $session"
#     invoked from within
# "if { $done_something == 0 } {
#
#     if { ! $fmri(inmelodic) } {
#        if { $fmri(level) == 1 } {
# 	      for { set session 1 } { $session <= $fmri(mult..."
#     (file "/usr/share/fsl/5.0/bin/feat" line 387)
# b 64 Doors
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3848/L1_task-srDoorsb_model-01_type-act_run-02_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# child process exited abnormally
#     while executing
# "fsl:exec "${FSLDIR}/bin/feat_model design" $fmri(featModelOpts) -N feat0_model -l logs "
#     (procedure "firstLevelMaster" line 43)
#     invoked from within
# "firstLevelMaster $session"
#     invoked from within
# "if { $done_something == 0 } {
#
#     if { ! $fmri(inmelodic) } {
#        if { $fmri(level) == 1 } {
# 	      for { set session 1 } { $session <= $fmri(mult..."
#     (file "/usr/share/fsl/5.0/bin/feat" line 387)
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3848/L1_task-srDoorsa_model-01_type-act_run-02_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# /data/projects/STUDIES/social_doors_college
# child process exited abnormally
#     while executing
# "fsl:exec "${FSLDIR}/bin/feat_model design" $fmri(featModelOpts) -N feat0_model -l logs "
#     (procedure "firstLevelMaster" line 43)
#     invoked from within
# "firstLevelMaster $session"
#     invoked from within
# "if { $done_something == 0 } {
#
#     if { ! $fmri(inmelodic) } {
#        if { $fmri(level) == 1 } {
# 	      for { set session 1 } { $session <= $fmri(mult..."
#     (file "/usr/share/fsl/5.0/bin/feat" line 387)
# b 64 Doors
# child process exited abnormally
#     while executing
# "fsl:exec "${FSLDIR}/bin/feat_model design" $fmri(featModelOpts) -N feat0_model -l logs "
#     (procedure "firstLevelMaster" line 43)
#     invoked from within
# "firstLevelMaster $session"
#     invoked from within
# "if { $done_something == 0 } {
#
#     if { ! $fmri(inmelodic) } {
#        if { $fmri(level) == 1 } {
# 	      for { set session 1 } { $session <= $fmri(mult..."
#     (file "/usr/share/fsl/5.0/bin/feat" line 387)
# a 64 Social
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3848/L1_task-srSociala_model-01_type-act_run-02_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3848/L1_task-srSociala_model-01_type-act_run-01_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# b 66 Social
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3848/L1_task-srSocialb_model-01_type-act_run-02_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3848/L1_task-srSocialb_model-01_type-act_run-01_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# a 64 Social
# b 66 Social
# 3992
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3892
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3864
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3912
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3880
# a 64 Social
# ./models/L1_task-srSociala_model-01.sh: line 58: /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3880/L1_task-srSociala_model-01_seed-0_run-02_variant-dctAROMAnonaggr.fsf: No such file or directory
# grep: /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3880/L1_task-srSociala_model-01_seed-0_run-02_variant-dctAROMAnonaggr.fsf: No such file or directory
#     while executing
# "exec sh -c "grep -a 'fmri(inmelodic)' $filename | tail -n 1 | awk '{ print \$3 }'" "
#     (procedure "feat5:load" line 5)
#     invoked from within
# "feat5:load -1 1 ${fsfroot}.fsf"
#     (file "/usr/share/fsl/5.0/bin/feat" line 306)
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3880/L1_task-srSociala_model-01_type-act_run-01_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# b 66 Social
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3880/L1_task-srSocialb_model-01_type-act_run-02_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3880/L1_task-srSocialb_model-01_type-act_run-01_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# a 64 Social
# To view the FEAT progress and final report, point your web browser at /data/projects/STUDIES/social_doors_college/derivatives/fsl/results/lowerLv_results/sub-3880/L1_task-srSociala_model-01_type-act_run-02_sm-6_variant-dctAROMAnonaggr.feat/report_log.html
# b 66 Social
# 3891
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3855
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3910
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3871
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3893
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 66 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3887
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 3895
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
# 3851
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Social
# b 64 Social
# a 66 Social
# b 64 Social
# 4018
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 66 Doors
# /data/projects/STUDIES/social_doors_college
# /data/projects/STUDIES/social_doors_college
# b 64 Doors
# a 64 Social
# b 66 Social
# a 64 Social
# b 66 Social
